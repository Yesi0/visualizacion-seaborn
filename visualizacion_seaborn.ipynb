# %% [markdown]
# <a href="https://colab.research.google.com/github/Yesi0/visualizacion-seaborn/blob/main/visualizacion_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('credit_card.csv') #importamos la base de datos
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos = pd.read_csv('credit_card.csv') #guardamos la base de datos, en la variable datos

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# # 1.2Traduciendo variables

# %%
datos.columns #mjuestra el nombre de todas las columnas
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
#Creamos un diccionadio con el nombre de las columnas de arriba y le ponemos un nuevo nombre
dic_columnas = {
    'LIMIT_BAL' : 'limite',
    'CHECKING_ACCOUNT' : 'cuenta_corriente',
    'EDUCATION' : 'escolaridad',
    'MARRIAGE' : 'estado_civil',
    'AGE' : 'edad',
    'BILL_AMT' : 'valor_factura',
    'PAY_AMT' : 'valor_pago',
    'DEFAULT' : 'moroso'
}

# %%
#creamos una nueva base de datos donde se guardara la informacion que estamos cambiando, la nueva base de datos tarjeta, donde se interpeta:
#la base de datos llamada datos, le cambiamos el nombre (rename) a las columnas (columns), con el nombre del diccionario que creamos arriba (dic_columnas)
tarjetas = datos.rename(columns = dic_columnas)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
#ahora cambiamos el nombre de las variables que estan dentro de las columnas, o sea los valores, como 'Yes', 'university', 'single' etc...
tarjetas.cuenta_corriente.unique()  # aqui llamamos a la columna cuenta corriente, y que nos traiga solo los valores unicos que tiene (unique), donde nos trae Yes y No
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#cambiando el nombre a los valores, parecido cuando cambiamos el nombre de las columnas
dic_cuenta = {
    'Yes' : 'Si',
    'No' : 'No'
}

# %%
tarjetas.cuenta_corriente.map(dic_cuenta) #visualizamos como queda el cambio
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
#ahora agregamos los cambios a la base de datos
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta) # map() es un método que se puede aplicar a una columna (o Serie) de un DataFrame. Lo que hace es "mapear" o "transformar" los valores de esa columna según un diccionario, función u otra Serie.

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University' : '2.Universidad',
    '3.Graduate School' : '3.Pos-graduación',
    '1.High School' : '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married' : 'Casado/a',
    'Single' : 'Soltero/a'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# #2.Analisis exploratorio de variables

# %% [markdown]
# #2.2 Importando Seaborn y análisis de distribución

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: lida, missingno

# %%
tarjetas.shape #para saber  cuantas columnas y filas tiene la base de datos
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
#la columna limite, es el cupo total que tienen los clientes, en la tarjeta
sns.displot(tarjetas['limite']); #visualizar grafico, de la base de datos tarjeta, la columna que queremos ver que es limte, es un HISTOGRAMA o sea, grafico de fecuencia

# %%
#otra forma de hacer ese mismo grafico
sns.displot(data=tarjetas, x='limite');

# %%
#aqui podemos ver las distribucion de todas las variables de una columna (hue)
sns.displot(data=tarjetas, x='limite', hue='escolaridad');

# %% [markdown]
# #2.3 Creando variable numérica

# %%
#creamos una nueva columna donde calculamos el % que el cliente uso de la tarjeta
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['limite'] #iu = indice de uso, valor factura es el monto que uso de la tarjeta, y limite es el cupo total

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
#graficamos
sns.displot(data=tarjetas, x='iu');
#interpetacion grafico de abajo: hay un porcentaje alto que no ocupa mucho el cupo total de la tarjeta

# %% [markdown]
# Hay un publico signiifacito que usa poco el limite que tiene disponible

# %% [markdown]
# #2.4  Parámetros de gráficos

# %%
sns.set_style('darkgrid') #con esto ponemos el fondo con lienas cuadriculadas

# %% [markdown]
# https://matplotlib.org/stable/

# %%
sns.displot(data=tarjetas, x='limite', hue='escolaridad', palette= 'inferno'); #palette= 'inferno' pallete para cambiar el color de las barras del grafico, inferno es el color

# %% [markdown]
# #3. Comparando y analizando variables categoricas

# %% [markdown]
# #3.2 Countplot, catplot y swarmplot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
#visualizar variables categoricas (que NO son numericas)
sns.countplot(x='cuenta_corriente', data=tarjetas); #primero ponemos el eje x con la variable que queremos ver, y luego la base de datos

# %% [markdown]
# hay mas de 800 personas que tienen cuenta corriente y un poco mas de 600 que no la tienen

# %%
#para ver 2 variables, en este caso cuantas personas morosas tienen cuenta corriente, donde 1 es moroso y 0 no lo es.
sns.countplot(x='cuenta_corriente', data=tarjetas, hue='moroso');

# %% [markdown]
# Aqui nos indica que hay mas personas morosas que NO tienen cuenta corriente

# %%
#grafico de dispercions, en este caso analizamos una variable numerica y otra cualitaitva, no olvidar poner la base de datos
sns.catplot(x='estado_civil', y='limite', data=tarjetas);

# %%
#ahora vemos que grupo es mas moroso, si los solteros o casados
sns.catplot(x='estado_civil', y='limite', data=tarjetas, hue='moroso', dodge=True); #dodge=True es para que el grafico de moroso se separe de la otra variable y se vea mejor

# %% [markdown]
# podemos analizar que las personas solteras con menor limite son mas morosas

# %%
#otro tipo de grafico, tambien es de puntos, pero a diferencia del de arriba, los puntos no se sobreponen
sns.swarmplot(x='escolaridad', y ='iu', data=tarjetas);
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 27.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Analizando el graifoc, podemos observar quew el grupo de colegio, esta poco distribuida, tiene 2 grandes volumnes donde por una parte muy pocos tienen un uno menor al 20% y otro grupo tiene un uso cercano al 100%.

# %% [markdown]
# #3.3 Boxplot y Violinplot

# %%
sns.boxplot(x='escolaridad', y='iu', data=tarjetas);

# %% [markdown]
# en promedio el grupo de colegio tiene un uso mayor de la tarjeta de credito que los otros 2 grupos, por lo que se puee concluir que ha medida que tiene un nivel de escolaridad mas alto su iu disminuye, esto se puede producir porque quiza tenga un limite de cupo mas alto

# %%
sns.boxplot(x='escolaridad', y='iu', data=tarjetas, hue='moroso', palette='bone'); #recordar que palette es para cambiar el color del grafico

# %% [markdown]
# en todos los grupos la media de las personas que son morosas, es mas alta de las personas que no lo son, por lo que podemos decir, que las personas morosas tienden a usar mas el limite de la tarjeta de credito

# %%
sns.violinplot(x='escolaridad', y='iu', data=tarjetas, hue='moroso'); #este grafico nos sirve para ver la concentracion de los datos

# %% [markdown]
# #3.4 Creando y analizando variable categórica

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas.edad.unique() #vemos todas las edad con valores unicos que hay
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
#como son muchas edad, para graficar lo mejor es agrupar
bins = [20,30,40,50,60,100] #creamo una lista con el rango de edades
nombres=['20-29', '30-39', '40-49', '50-59', '60+'] #creamos nombres a los rango de edad

#ahora creammos la columna en la base de datos
tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], bins, labels=nombres, right=False) #agrupamos (con cut) la edad de la data tarjetas, ponemos los valores (bins) y label es como se va agrupar estas edad, la variable que creamos que se llama nombres,
                                                                                      #right=False a pd.cut() para indicar que el intervalo es cerrado por la izquierda, es decir, un valor exacto como 30 se clasificará como '30-39' en lugar de '20-29'.

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-29
# 1       519.3975      0.0000       1  0.014375      20-29
# 2      4223.5297    457.0698       0  0.155856      30-39
# 3     14522.9563    602.2000       0  0.964660      30-39
# 4    124060.1253  16560.5000       0  0.824046      20-29

# %%
sns.boxplot(x='rango_edad', y='limite', data=tarjetas);

# %% [markdown]
# podemos ver que el rango de edad mayor a 60 usan mas el limite de la tarjeta de credito muy seguido de las personas que tienen entre 30 a 50, por otro lado las personas mas jovenes entre 20 y 29 son las que menos ocupan la tarjeta de credito

# %% [markdown]
# #4. Analisis de variables numericas y regresion

# %% [markdown]
# #4.2 Displot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-29
# 1       519.3975      0.0000       1  0.014375      20-29
# 2      4223.5297    457.0698       0  0.155856      30-39
# 3     14522.9563    602.2000       0  0.964660      30-39
# 4    124060.1253  16560.5000       0  0.824046      20-29

# %%
sns.displot(data=tarjetas, x='limite', hue='escolaridad'); #grafico de distriubcion

# %%
sns.displot(data=tarjetas, x='limite', col='escolaridad'); #con col, lo que hace es crear un grafico por cada variable que tiene escolaridad

# %%
sns.displot(data=tarjetas, x='limite', col='escolaridad', kind='kde'); #con kind vemos la densidad

# %%
sns.displot(data=tarjetas, x='limite', col='escolaridad', kind='kde', hue='moroso'); #nos indica que grupo es mas moroso

# %%
sns.displot(data=tarjetas, x='limite', col='escolaridad', kind='kde', hue='rango_edad');

# %% [markdown]
# #4.3 Scatterplot y lmplot

# %%
sns.scatterplot(x='iu', y ='valor_factura', data=tarjetas); #esta es un grafico de dispercion, que se pueden comparar variables numericas entre ellas mismas

# %% [markdown]
# podemos ver que tiene una relacion directamente proporcional, a medida que aumenta el valor de la factura, aumenta el indice de uso

# %%
sns.scatterplot(x='iu', y ='valor_factura', data=tarjetas, hue='cuenta_corriente'); #recordar que hue es para poner una segunda variable a analizar

# %%
sns.lmplot(x='iu', y ='valor_factura', data=tarjetas); #es parecido al grafico de arriba, pero aqui nos marca una linea de tendencia

# %% [markdown]
# #4.4 Test de hipótesis

# %%
sns.lmplot(x='iu', y ='valor_factura', data=tarjetas, col='moroso'); #recordar que col, es para 'abrir' el grafico, o sea separalo, en este caso van haber 2 graficos de morosos, 1 moroso y el otro de no moroso

# %%
from scipy.stats import ranksums #importando libreria para hacer hipotesis

# %% [markdown]
# Creamos nuestras 2 hipotesis
# - Hipotesis null = La distribucion de los grupos moroso y no moroso es la misma
# - Hipotesis alterntativa = La distribucion de los grupos moroso y no moroso NO es la misma

# %%
#Hacemos la consulta con query, query nos permite filtrar bajo condiciones dadas
#con query moroso ==1, Está filtrando el DataFrame para seleccionar solo las filas donde el valor en la columna moroso es igual a 1. Es decir, está seleccionando a los clientes que son morosos.
#El código selecciona los valores de la columna valor_factura del DataFrame tarjetas para aquellos clientes que son morosos (donde el valor en la columna moroso es igual a 1) y almacena el resultado en la variable moroso.
moroso = tarjetas.query("moroso == 1").valor_factura

# %%
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %% [markdown]
# Aqui tenemos el total de facturas de las personas  morosas, que son 117

# %%
no_moroso = tarjetas.query("moroso == 0").valor_factura

# %%
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: valor_factura, Length: 1383, dtype: float64

# %% [markdown]
# Aqui tenemos el total de facturas de las personas NO morosas, que son 1383

# %%
#con esta funcion podemos ver si la distribucion entre las 2 variables (moroso y no moroso) es significativa
resultado = ranksums(moroso, no_moroso) #usamos ranksums para ver si la distribucion es significativas, y dentro de los parentesis ponemos las variables que vamos a analizar

# %%
resultado
# Out:
# RanksumsResult(statistic=-2.562530598426702, pvalue=0.010391243081223555)

# %% [markdown]
# Nos enfocamos en el resultado pvalue, que en este caso es un 1%, los valores bajo del 5% sirve para aceptar nuestra hipotesis alternativa (que pusimos al principio)

# %%
print(f'El p_value de nuestro test es: {resultado.pvalue}')
# Out:
# El p_value de nuestro test es: 0.010391243081223555

# %% [markdown]
# Interpretacion: el pvalue es de 1%, lo que nos permite aceptar uestra hipotesis alternativa, es decir que la distribucion de los morosos y NO morosos no es la misma.

# %% [markdown]
# #5. Analisis conjunta de variables

# %% [markdown]
# #5.2 Jointplot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad     Casado/a    24
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-29
# 1       519.3975      0.0000       1  0.014375      20-29
# 2      4223.5297    457.0698       0  0.155856      30-39
# 3     14522.9563    602.2000       0  0.964660      30-39
# 4    124060.1253  16560.5000       0  0.824046      20-29

# %%
sns.jointplot(x='edad', y ='limite', data=tarjetas);

# %% [markdown]
# el grafico de arriba, representa la distribucion de las edades, donde la edad se concentra mas en los 30 años, y el grafico de la derecha, representa el limite, donde se puede ver que esta mas concentrado aprox en el limite 20.000

# %%
sns.jointplot(x='edad', y ='limite', data=tarjetas, kind='kde'); #recordar que kind=kde nos representa un grafico de lineas para ver la densidad

# %%
sns.jointplot(x='edad', y ='limite', data=tarjetas, kind='hex'); #aqui hay otra forma de ver el kind

# %% [markdown]
# En los puntos mas oscuros es donde tenemos mas concentracion

# %%
sns.jointplot(x='edad', y ='limite', data=tarjetas, kind='kde', hue='moroso'); #podemos incluir la variable moroso para visualizar tambien los morosos y no morosos

# %% [markdown]
# #5.3 Pairplot

# %%
tarjetas.describe() #vemos un analisis rapido las nuestra variables numericas
# Out:
#               limite         edad  valor_factura    valor_pago       moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 iu
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
sns.pairplot(data=tarjetas) #analisis para ver como se relacionan las variables entre si

# %% [markdown]
# El histograma nos meustra el compotamiento de una varibale con sigo misma, para ver su frecuencia ej: lado vertical edad, con lado horizontal edad

# %%
sns.pairplot(data=tarjetas, hue='escolaridad', palette = 'cividis')
